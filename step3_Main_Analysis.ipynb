# %% [markdown]
# ## Importing Required Packages

# %%
import os
import numpy as np
import pandas as pd
import statistics
import rioxarray
import xarray as xr
import rasterio
import statistics
from tqdm import tqdm

# %% [markdown]
# ## Function to convert data to annualy

# %%
def aggregate_to_annual(data_array):
    """
    Aggregate monthly data to annual values.
    """
    return data_array.resample(time='A').mean(dim='time')

# %% [markdown]
# ## Function to calculate max and min value per cell
# Also also applying first filter

# %%
def calculate_max_min_per_cell(data_array):
    """
    Calculate the maximum and minimum values excluding outliers
    """
    mean_val = data_array.mean(dim='time')
    std_val = data_array.std(dim='time')
    
    # Exclude outliers within each grid cell
    valid_data = data_array.where((data_array >= (mean_val - 3 * std_val)) & (data_array <= (mean_val + 3 * std_val)), other=np.nan)
    
    # Calculate the maximum and minimum values for each cell after excluding outliers
    max_val_per_cell = valid_data.max(dim='time')
    min_val_per_cell = valid_data.min(dim='time')
    
    return max_val_per_cell, min_val_per_cell

# %% [markdown]
# ## Load Data

# %%
# Define paths to your data
data_dir = "../Processed_Data/HTI_Indices_Resampled/"
koppen_map_path = "../Raw_Data/koppen_geiger_0p5.tif"
output_path = "../Processed Data/Output of analysis"

# Load Koppen map
koppen_data = rioxarray.open_rasterio(koppen_map_path).squeeze()
regions = np.unique(koppen_data)

# Models and indices
models = os.listdir(data_dir)
scenarios = ['SSP585']
indices = ["AT_in", "AT_out", "DI", "ET", "HI", "HMI", "MDI", "NET", "SAT", "sWGBT", "WBT", "WCT"]  # Replace with actual indices names

max_min_results = {region: {index: {model: {"max": None, "min": None, "max_cross_consi": None, "min_cross_consi": None, "max_cross_years": [], "min_cross_years": []} for model in models} for index in indices}  for region in regions}

# %% [markdown]
# ## Finding Max and Min Values of Indices on historical Period (1850-2014)

# %%
for model in models:
    print(f'Precssing of {model} is started')
    model_dir = os.path.join(data_dir, model)
    model_dir_historical = os.path.join(data_dir, model, 'Historical')
    
    for index in tqdm(indices,"processing Indices"):
        
        index_file = os.path.join(model_dir_historical, f'resampled_{index}.nc')
        data_array_historical = xr.open_dataset(index_file)[index]
        data_array_annual_historical = aggregate_to_annual(data_array_historical)
        
        max_val, min_val = calculate_max_min_per_cell(data_array_annual_historical)  # got historical max and min value per cell of index
        
        for region in regions:
            region_mask = (koppen_data == region).compute()
            
            region_max_val_per_cell = max_val.where(region_mask, other = np.nan)
            region_min_val_per_cell = min_val.where(region_mask, other = np.nan)
            
            region_mean_of_max_val_per_cell = region_max_val_per_cell.mean()
            region_mean_of_min_val_per_cell = region_min_val_per_cell.mean()
            
            region_std_of_max_val_per_cell = region_max_val_per_cell.std()
            region_std_of_min_val_per_cell = region_min_val_per_cell.std()
          
            Valid_max_val_for_region = region_max_val_per_cell.where((region_max_val_per_cell >= (region_mean_of_max_val_per_cell-3*region_std_of_max_val_per_cell)) & (region_max_val_per_cell <= (region_mean_of_max_val_per_cell + 3*region_std_of_max_val_per_cell)) , other = np.nan)
            
            Valid_min_val_for_region = region_min_val_per_cell.where((region_min_val_per_cell >= (region_mean_of_min_val_per_cell-3*region_std_of_min_val_per_cell)) & (region_min_val_per_cell <= (region_mean_of_min_val_per_cell + 3*region_std_of_min_val_per_cell)) , other = np.nan)
            
            max_val_of_index_for_this_region = Valid_max_val_for_region.max()
            min_val_of_index_for_this_region = Valid_min_val_for_region.min()
            
            max_min_results[region][index][model]["max"] = max_val_of_index_for_this_region
            max_min_results[region][index][model]["min"] = min_val_of_index_for_this_region
            
    print(f'Processing of {model} is Done\n')
# Out:
# Precssing of IIT-ESM (INDIA) is started
# processing Indices: 100%|██████████████████████████████████████████████████████████████| 12/12 [01:33<00:00,  7.76s/it]
# Processing of IIT-ESM (INDIA) is Done

# %% [markdown]
# ## Finding Exposure Timing

# %%
for model in models:
    print(f'Precssing of {model} is started')
    model_dir = os.path.join(data_dir, 'IIT-ESM (INDIA)')
    
    for scenario in scenarios:
        scenario_dir = os.path.join(model_dir,scenario)

        for index in tqdm(indices,"processing Indices"):
            index_file_of_scenario = os.path.join(scenario_dir,f'resampled_{index}.nc')
            data_array_scenario = xr.open_dataset(index_file_of_scenario)[index]
            data_array_annual_scenario = aggregate_to_annual(data_array_scenario)
            
            #filtering######################
            mean_val = data_array_annual_scenario.mean(dim='time')
            std_val = data_array_annual_scenario.std(dim='time')

            # Exclude outliers within each grid cell
            valid_data = data_array_annual_scenario.where((data_array_annual_scenario >= (mean_val - 3 * std_val)) & (data_array_annual_scenario <= (mean_val + 3 * std_val)), other=np.nan)
            data_array_annual_scenario = valid_data
            ################################
            
            filtered_scenario_data = data_array_annual_scenario  # for now assuming filter is applied

            for region in regions:

                region_mask = (koppen_data == region).compute()
                
                region_data = filtered_scenario_data.where(region_mask, other = np.nan)

                max_cross_year = [] # years when index value will be higher than its historical max
                min_cross_year = [] # years when index value will be lower than its historical min

                max_value_for_region_per_year = region_data.max(dim='x').max(dim='y')
                min_value_for_region_per_year = region_data.min(dim='x').min(dim='y')
                
                
                for i in range(85):
                    if max_value_for_region_per_year[i] > max_min_results[region][index][model]["max"]:
                        max_cross_year.append(2015+i)
                    if min_value_for_region_per_year[i] < max_min_results[region][index][model]["min"]:
                        min_cross_year.append(2015+i)
                
                max_min_results[region][index][model]["max_cross_years"] = max_cross_year
                max_min_results[region][index][model]["min_cross_years"] = min_cross_year
                
                max_count = 1
                max_consi_yearyear= None
                
                for i in range(len(max_cross_year)):
                    if(i==0):
                        continue
                    else:
                        if(max_cross_year[i] == max_cross_year[i-1]+1):
                            if(max_consi_year == None):
                                max_consi_year = max_cross_year[i-1]
                            max_count= max_count+1
                            if(max_count>=5):
                                break
                        else:
                            if(max_count>=5):
                                break
                            else:
                                max_count=1;
                                max_consi_year = None
                                
                    if (i == (len(max_cross_year)-1)) & (max_count<5):
                        max_consi_year = None;
                        
                
                min_count = 1
                min_consi_year= None
                
                for j in range(len(min_cross_year)):
                    if(j == 0):
                        continue
                    else:
                        if(min_cross_year[j] == min_cross_year[j-1]+1):
                            if(min_consi_year == None):
                                min_consi_year = min_cross_year[j-1]
                            min_count= min_count+1
                            if(min_count>=5):
                                break
                        else:
                            if(min_count>=5):
                                break
                            else:
                                min_count=1;
                                min_consi_year = None
                    if (j == (len(max_cross_year)-1)) & (max_count<5):
                        max_consi_year = None;
                
                max_min_results[region][index][model]["max_cross_consi"] = max_consi_year
                max_min_results[region][index][model]["min_cross_consi"] = min_consi_year
# Out:
# Precssing of IIT-ESM (INDIA) is started
# processing Indices: 100%|██████████████████████████████████████████████████████████████| 12/12 [02:09<00:00, 10.78s/it]

# %% [markdown]
# ## Summary of Max & min values in history and exposure time of future of different models

# %%
summary_results = []

for region in regions:
    for index in indices:
        for model in models:
            #numpy_array = max_min_results[region][model][index]["max"].to_numpy()
            max_vals = max_min_results[region][index][model]["max"].values
            min_vals = max_min_results[region][index][model]["min"].values

            max_ = np.nanmedian(max_vals)
            min_ = np.nanmedian(min_vals)
            
            summary_results.append({
                "Region": region,
                "Index": index,
                "Model": model,
                "Max": max_,
                "Min": min_,
                "Max_Cross_start": max_min_results[region][index][model]["max_cross_consi"],
                "Min_Cross_start": max_min_results[region][index][model]["min_cross_consi"],
                "Max_Cross_Years": max_min_results[region][index][model]["max_cross_years"],
                "Min_Cross_Years": max_min_results[region][index][model]["min_cross_years"],
            })

summary_df = pd.DataFrame(summary_results)

# %% [markdown]
# Styling the dataframe

# %%
styled_df = summary_df.style.set_properties(**{'text-align': 'center'})
styled_df = styled_df.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
styled_df = styled_df.set_table_styles([dict(selector='td', props=[('text-align', 'right')])])
styled_df = styled_df.set_table_styles([dict(selector='th', props=[('font-weight', 'bold')])])
styled_df = styled_df.set_table_styles([dict(selector='td', props=[('font-weight', 'normal')])])
styled_df = styled_df.set_table_styles([dict(selector='th', props=[('background-color', '#f2f2f2')])])
styled_df = styled_df.set_table_styles([dict(selector='td', props=[('background-color', '#e6e6e6')])])
styled_df = styled_df.set_table_styles([dict(selector='th', props=[('border-bottom', '1px solid #ddd')])])
styled_df = styled_df.set_table_styles([dict(selector='td', props=[('border-bottom', '1px solid #ddd')])])
styled_df = styled_df.set_caption('Abrupt Values')
styled_df = styled_df.format({ "Region": "{:.0f}",  "Max": "{:.2f}", "Min": "{:.2f}" })
styled_df = styled_df.hide(axis='index')
styled_df = styled_df.background_gradient(cmap='coolwarm')

#styled_df = styled_df.bar(subset=['Max', 'Min'])

# To display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_6082c td {
#   border-bottom: 1px solid #ddd;
# }
# #T_6082c_row0_col0, #T_6082c_row1_col0, #T_6082c_row2_col0, #T_6082c_row3_col0, #T_6082c_row4_col0, #T_6082c_row5_col0, #T_6082c_row6_col0, #T_6082c_row7_col0, #T_6082c_row8_col0, #T_6082c_row9_col0, #T_6082c_row10_col0, #T_6082c_row11_col0, #T_6082c_row12_col6, #T_6082c_row13_col6, #T_6082c_row14_col6, #T_6082c_row15_col6, #T_6082c_row17_col6, #T_6082c_row18_col6, #T_6082c_row19_col6, #T_6082c_row20_col6, #T_6082c_row21_col6, #T_6082c_row22_col6, #T_6082c_row23_col6, #T_6082c_row24_col6, #T_6082c_row25_col6, #T_6082c_row26_col6, #T_6082c_row27_col6, #T_6082c_row28_col6, #T_6082c_row29_col6, #T_6082c_row30_col6, #T_6082c_row31_col6, #T_6082c_row32_col6, #T_6082c_row33_col6, #T_6082c_row34_col6, #T_6082c_row35_col6, #T_6082c_row36_col6, #T_6082c_row37_col6, #T_6082c_row38_col6, #T_6082c_row39_col6, #T_6082c_row41_col6, #T_6082c_row42_col6, #T_6082c_row43_col6, #T_6082c_row44_col6, #T_6082c_row45_col6, #T_6082c_row46_col6, #T_6082c_row47_col6, #T_6082c_row48_col6, #T_6082c_row49_col6, #T_6082c_row50_col6, #T_6082c_row51_col6, #T_6082c_row52_col6, #T_6082c_row53_col6, #T_6082c_row54_col6, #T_6082c_row55_col6, #T_6082c_row56_col6, #T_6082c_row57_col6, #T_6082c_row58_col6, #T_6082c_row59_col6, #T_6082c_row60_col6, #T_6082c_row61_col6, #T_6082c_row62_col6, #T_6082c_row63_col6, #T_6082c_row64_col6, #T_6082c_row65_col6, #T_6082c_row66_col6, #T_6082c_row67_col6, #T_6082c_row68_col6, #T_6082c_row69_col6, #T_6082c_row70_col6, #T_6082c_row71_col6, #T_6082c_row72_col6, #T_6082c_row73_col6, #T_6082c_row74_col6, #T_6082c_row75_col6, #T_6082c_row77_col6, #T_6082c_row78_col6, #T_6082c_row79_col6, #T_6082c_row80_col6, #T_6082c_row81_col6, #T_6082c_row82_col6, #T_6082c_row83_col6, #T_6082c_row84_col6, #T_6082c_row85_col6, #T_6082c_row86_col6, #T_6082c_row87_col6, #T_6082c_row89_col6, #T_6082c_row90_col6, #T_6082c_row91_col6, #T_6082c_row92_col6, #T_6082c_row93_col6, #T_6082c_row95_col6, #T_6082c_row98_col6, #T_6082c_row102_col6, #T_6082c_row160_col4, #T_6082c_row169_col5, #T_6082c_row172_col3, #T_6082c_row195_col6, #T_6082c_row197_col6, #T_6082c_row199_col6, #T_6082c_row200_col6, #T_6082c_row201_col6, #T_6082c_row328_col4 {
#   text-align: center;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6082c_row0_col1, #T_6082c_row0_col2, #T_6082c_row0_col7, #T_6082c_row0_col8, #T_6082c_row1_col1, #T_6082c_row1_col2, #T_6082c_row1_col7, #T_6082c_row1_col8, #T_6082c_row2_col1, #T_6082c_row2_col2, #T_6082c_row2_col7, #T_6082c_row2_col8, #T_6082c_row3_col1, #T_6082c_row3_col2, #T_6082c_row3_col7, #T_6082c_row3_col8, #T_6082c_row4_col1, #T_6082c_row4_col2, #T_6082c_row4_col7, #T_6082c_row4_col8, #T_6082c_row5_col1, #T_6082c_row5_col2, #T_6082c_row5_col7, #T_6082c_row5_col8, #T_6082c_row6_col1, #T_6082c_row6_col2, #T_6082c_row6_col7, #T_6082c_row6_col8, #T_6082c_row7_col1, #T_6082c_row7_col2, #T_6082c_row7_col7, #T_6082c_row7_col8, #T_6082c_row8_col1, #T_6082c_row8_col2, #T_6082c_row8_col7, #T_6082c_row8_col8, #T_6082c_row9_col1, #T_6082c_row9_col2, #T_6082c_row9_col7, #T_6082c_row9_col8, #T_6082c_row10_col1, #T_6082c_row10_col2, #T_6082c_row10_col7, #T_6082c_row10_col8, #T_6082c_row11_col1, #T_6082c_row11_col2, #T_6082c_row11_col7, #T_6082c_row11_col8, #T_6082c_row12_col1, #T_6082c_row12_col2, #T_6082c_row12_col7, #T_6082c_row12_col8, #T_6082c_row13_col1, #T_6082c_row13_col2, #T_6082c_row13_col7, #T_6082c_row13_col8, #T_6082c_row14_col1, #T_6082c_row14_col2, #T_6082c_row14_col7, #T_6082c_row14_col8, #T_6082c_row15_col1, #T_6082c_row15_col2, #T_6082c_row15_col7, #T_6082c_row15_col8, #T_6082c_row16_col1, #T_6082c_row16_col2, #T_6082c_row16_col7, #T_6082c_row16_col8, #T_6082c_row17_col1, #T_6082c_row17_col2, #T_6082c_row17_col7, #T_6082c_row17_col8, #T_6082c_row18_col1, #T_6082c_row18_col2, #T_6082c_row18_col7, #T_6082c_row18_col8, #T_6082c_row19_col1, #T_6082c_row19_col2, #T_6082c_row19_col7, #T_6082c_row19_col8, #T_6082c_row20_col1, #T_6082c_row20_col2, #T_6082c_row20_col7, #T_6082c_row20_col8, #T_6082c_row21_col1, #T_6082c_row21_col2, #T_6082c_row21_col7, #T_6082c_row21_col8, #T_6082c_row22_col1, #T_6082c_row22_col2, #T_6082c_row22_col7, #T_6082c_row22_col8, #T_6082c_row23_col1, #T_6082c_row23_col2, #T_6082c_row23_col7, #T_6082c_row23_col8, #T_6082c_row24_col1, #T_6082c_row24_col2, #T_6082c_row24_col7, #T_6082c_row24_col8, #T_6082c_row25_col1, #T_6082c_row25_col2, #T_6082c_row25_col7, #T_6082c_row25_col8, #T_6082c_row26_col1, #T_6082c_row26_col2, #T_6082c_row26_col7, #T_6082c_row26_col8, #T_6082c_row27_col1, #T_6082c_row27_col2, #T_6082c_row27_col7, #T_6082c_row27_col8, #T_6082c_row28_col1, #T_6082c_row28_col2, #T_6082c_row28_col7, #T_6082c_row28_col8, #T_6082c_row29_col1, #T_6082c_row29_col2, #T_6082c_row29_col7, #T_6082c_row29_col8, #T_6082c_row30_col1, #T_6082c_row30_col2, #T_6082c_row30_col7, #T_6082c_row30_col8, #T_6082c_row31_col1, #T_6082c_row31_col2, #T_6082c_row31_col7, #T_6082c_row31_col8, #T_6082c_row32_col1, #T_6082c_row32_col2, #T_6082c_row32_col7, #T_6082c_row32_col8, #T_6082c_row33_col1, #T_6082c_row33_col2, #T_6082c_row33_col7, #T_6082c_row33_col8, #T_6082c_row34_col1, #T_6082c_row34_col2, #T_6082c_row34_col7, #T_6082c_row34_col8, #T_6082c_row35_col1, #T_6082c_row35_col2, #T_6082c_row35_col7, #T_6082c_row35_col8, #T_6082c_row36_col1, #T_6082c_row36_col2, #T_6082c_row36_col7, #T_6082c_row36_col8, #T_6082c_row37_col1, #T_6082c_row37_col2, #T_6082c_row37_col7, #T_6082c_row37_col8, #T_6082c_row38_col1, #T_6082c_row38_col2, #T_6082c_row38_col7, #T_6082c_row38_col8, #T_6082c_row39_col1, #T_6082c_row39_col2, #T_6082c_row39_col7, #T_6082c_row39_col8, #T_6082c_row40_col1, #T_6082c_row40_col2, #T_6082c_row40_col7, #T_6082c_row40_col8, #T_6082c_row41_col1, #T_6082c_row41_col2, #T_6082c_row41_col7, #T_6082c_row41_col8, #T_6082c_row42_col1, #T_6082c_row42_col2, #T_6082c_row42_col7, #T_6082c_row42_col8, #T_6082c_row43_col1, #T_6082c_row43_col2, #T_6082c_row43_col7, #T_6082c_row43_col8, #T_6082c_row44_col1, #T_6082c_row44_col2, #T_6082c_row44_col7, #T_6082c_row44_col8, #T_6082c_row45_col1, #T_6082c_row45_col2, #T_6082c_row45_col7, #T_6082c_row45_col8, #T_6082c_row46_col1, #T_6082c_row46_col2, #T_6082c_row46_col7, #T_6082c_row46_col8, #T_6082c_row47_col1, #T_6082c_row47_col2, #T_6082c_row47_col7, #T_6082c_row47_col8, #T_6082c ...

# %%
styled_df.to_html('../Processed_Data/Output of analysis/max_min_values.html')

# %%
styled_df.to_excel('../Processed_Data/Output of analysis/max_min_values.xlsx')

# %%
summary_df.to_csv('../Processed_Data/Output of analysis/max_min_values.csv')

# %% [markdown]
# ## Finding one value of time median

# %%
final_results = {region: {index: {"median_max_cross_consi": None, "median_min_cross_consi": None} for index in indices}  for region in regions}

for region in regions:
    for index in indices:
        max_list = []
        min_list = []
        
        for model in models:
            if max_min_results[region][index][model]['max_cross_consi']:
                max_list.append(max_min_results[region][index][model]['max_cross_consi'])
            if max_min_results[region][index][model]['min_cross_consi']:
                min_list.append(max_min_results[region][index][model]['min_cross_consi'])
        
        if len(max_list)!=0:
            final_results[region][index]['median_max_cross_consi'] = statistics.median(max_list)
        if len(min_list)!=0:
            final_results[region][index]['median_min_cross_consi'] = statistics.median(min_list)

# %%
summary_median= []

for region in regions:
    for index in indices:
            
        summary_median.append({
            "Region": region,
            "Index": index,
            "Max_Median": final_results[region][index]['median_max_cross_consi'],
            "Min_Median": final_results[region][index]['median_min_cross_consi']
        })


summary_median_df = pd.DataFrame(summary_median)

# %%
styled_median_df = summary_median_df.style.set_properties(**{'text-align': 'center'})
styled_median_df = styled_median_df.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='td', props=[('text-align', 'right')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='th', props=[('font-weight', 'bold')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='td', props=[('font-weight', 'normal')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='th', props=[('background-color', '#f2f2f2')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='td', props=[('background-color', '#e6e6e6')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='th', props=[('border-bottom', '1px solid #ddd')])])
styled_median_df = styled_median_df.set_table_styles([dict(selector='td', props=[('border-bottom', '1px solid #ddd')])])
styled_median_df = styled_median_df.set_caption('Abrupt Values')
styled_median_df = styled_median_df.format({ "Region": "{:.0f}",  "Max_Median": "{:.2f}", "Min_Median": "{:.2f}" })
styled_median_df = styled_median_df.hide(axis='index')
styled_median_df = styled_median_df.background_gradient(cmap='coolwarm')

#styled_df = styled_df.bar(subset=['Max_Median', 'Min_Median'])

# To display the styled DataFrame
styled_median_df
# Out:
# <style type="text/css">
# #T_8db43 td {
#   border-bottom: 1px solid #ddd;
# }
# #T_8db43_row0_col0, #T_8db43_row1_col0, #T_8db43_row2_col0, #T_8db43_row3_col0, #T_8db43_row4_col0, #T_8db43_row5_col0, #T_8db43_row6_col0, #T_8db43_row7_col0, #T_8db43_row8_col0, #T_8db43_row9_col0, #T_8db43_row10_col0, #T_8db43_row11_col0, #T_8db43_row12_col3, #T_8db43_row13_col3, #T_8db43_row14_col3, #T_8db43_row15_col3, #T_8db43_row17_col3, #T_8db43_row18_col3, #T_8db43_row19_col3, #T_8db43_row20_col3, #T_8db43_row21_col3, #T_8db43_row22_col3, #T_8db43_row23_col3, #T_8db43_row24_col3, #T_8db43_row25_col3, #T_8db43_row26_col3, #T_8db43_row27_col3, #T_8db43_row28_col3, #T_8db43_row29_col3, #T_8db43_row30_col3, #T_8db43_row31_col3, #T_8db43_row32_col3, #T_8db43_row33_col3, #T_8db43_row34_col3, #T_8db43_row35_col3, #T_8db43_row36_col3, #T_8db43_row37_col3, #T_8db43_row38_col3, #T_8db43_row39_col3, #T_8db43_row41_col3, #T_8db43_row42_col3, #T_8db43_row43_col3, #T_8db43_row44_col3, #T_8db43_row45_col3, #T_8db43_row46_col3, #T_8db43_row47_col3, #T_8db43_row48_col3, #T_8db43_row49_col3, #T_8db43_row50_col3, #T_8db43_row51_col3, #T_8db43_row52_col3, #T_8db43_row53_col3, #T_8db43_row54_col3, #T_8db43_row55_col3, #T_8db43_row56_col3, #T_8db43_row57_col3, #T_8db43_row58_col3, #T_8db43_row59_col3, #T_8db43_row60_col3, #T_8db43_row61_col3, #T_8db43_row62_col3, #T_8db43_row63_col3, #T_8db43_row64_col3, #T_8db43_row65_col3, #T_8db43_row66_col3, #T_8db43_row67_col3, #T_8db43_row68_col3, #T_8db43_row69_col3, #T_8db43_row70_col3, #T_8db43_row71_col3, #T_8db43_row72_col3, #T_8db43_row73_col3, #T_8db43_row74_col3, #T_8db43_row75_col3, #T_8db43_row77_col3, #T_8db43_row78_col3, #T_8db43_row79_col3, #T_8db43_row80_col3, #T_8db43_row81_col3, #T_8db43_row82_col3, #T_8db43_row83_col3, #T_8db43_row84_col3, #T_8db43_row85_col3, #T_8db43_row86_col3, #T_8db43_row87_col3, #T_8db43_row89_col3, #T_8db43_row90_col3, #T_8db43_row91_col3, #T_8db43_row92_col3, #T_8db43_row93_col3, #T_8db43_row95_col3, #T_8db43_row98_col3, #T_8db43_row102_col3, #T_8db43_row169_col2, #T_8db43_row195_col3, #T_8db43_row197_col3, #T_8db43_row199_col3, #T_8db43_row200_col3, #T_8db43_row201_col3 {
#   text-align: center;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8db43_row0_col1, #T_8db43_row1_col1, #T_8db43_row2_col1, #T_8db43_row3_col1, #T_8db43_row4_col1, #T_8db43_row5_col1, #T_8db43_row6_col1, #T_8db43_row7_col1, #T_8db43_row8_col1, #T_8db43_row9_col1, #T_8db43_row10_col1, #T_8db43_row11_col1, #T_8db43_row12_col1, #T_8db43_row13_col1, #T_8db43_row14_col1, #T_8db43_row15_col1, #T_8db43_row16_col1, #T_8db43_row17_col1, #T_8db43_row18_col1, #T_8db43_row19_col1, #T_8db43_row20_col1, #T_8db43_row21_col1, #T_8db43_row22_col1, #T_8db43_row23_col1, #T_8db43_row24_col1, #T_8db43_row25_col1, #T_8db43_row26_col1, #T_8db43_row27_col1, #T_8db43_row28_col1, #T_8db43_row29_col1, #T_8db43_row30_col1, #T_8db43_row31_col1, #T_8db43_row32_col1, #T_8db43_row33_col1, #T_8db43_row34_col1, #T_8db43_row35_col1, #T_8db43_row36_col1, #T_8db43_row37_col1, #T_8db43_row38_col1, #T_8db43_row39_col1, #T_8db43_row40_col1, #T_8db43_row41_col1, #T_8db43_row42_col1, #T_8db43_row43_col1, #T_8db43_row44_col1, #T_8db43_row45_col1, #T_8db43_row46_col1, #T_8db43_row47_col1, #T_8db43_row48_col1, #T_8db43_row49_col1, #T_8db43_row50_col1, #T_8db43_row51_col1, #T_8db43_row52_col1, #T_8db43_row53_col1, #T_8db43_row54_col1, #T_8db43_row55_col1, #T_8db43_row56_col1, #T_8db43_row57_col1, #T_8db43_row58_col1, #T_8db43_row59_col1, #T_8db43_row60_col1, #T_8db43_row61_col1, #T_8db43_row62_col1, #T_8db43_row63_col1, #T_8db43_row64_col1, #T_8db43_row65_col1, #T_8db43_row66_col1, #T_8db43_row67_col1, #T_8db43_row68_col1, #T_8db43_row69_col1, #T_8db43_row70_col1, #T_8db43_row71_col1, #T_8db43_row72_col1, #T_8db43_row73_col1, #T_8db43_row74_col1, #T_8db43_row75_col1, #T_8db43_row76_col1, #T_8db43_row77_col1, #T_8db43_row78_col1, #T_8db43_row79_col1, #T_8db43_row80_col1, #T_8db43_row81_col1, #T_8db43_row82_col1, #T_8db43_row83_col1, #T_8db43_row84_col1, #T_8db43_row85_col1, #T_8db43_row86_col1, #T_8db43_row87_col1, #T_8db43_row88_col1, #T_8db43_row89_col1, #T_8db43_row90_col1, #T_8db43_row91_col1, #T_8db43_row92_col1, #T_8db43_row93_col1, #T_8db43_row94_col1, #T_8db43_row95_col1, #T_8db43_row96_col1, #T_8db43_row97_col1, #T_8db43_row98_col1, #T_8db43_row99_col1, #T_8db43_row100_col1, #T_8db43_row101_col1, #T_8db43_row102_col1, #T_8db43_row103_col1, #T_8db43_row104_col1, #T_8db43_row105_col1, #T_8db43_row106_col1, #T_8db43_row107_col1, #T_8db43_row108_col1, #T_8db43_row109_col1, #T_8db43_row110_col1, #T_8db43_row111_col1, #T_8db43_row112_col1, #T_8db43_row113_col1, #T_8db43_row114_col1, #T_8db43_row115_col1, #T_8db43_row116_col1, #T_8db43_row117_col1, #T_8db43_row118_col1, #T_8db43_row119_col1, #T_8db43_row120_col1, #T_8db43_row121_col1, #T_8db43_row122_col1, #T_8db43_row123_col1, #T_8db43_row124_col1, #T_8db43_row125_col1, #T_8db43_row126_col1, #T_8db43_row127_col1, #T_8db43_row128_col1, #T_8db43_row129_col1, #T_8db43_row130_col1, #T_8db43_row131_col1, #T_8db43_row132_col1, #T_8db43_row133_col1, #T_8db43_row134_col1, #T_8db43_row135_col1, #T_8db43_row136_col1, #T_8db43_row137_col1, #T_8db43_row138_col1, #T_8db43_row139_col1, #T_8db43_row140_col1, #T_8db43_row141_col1, #T_8db43_row142_col1, #T_8db43_row143_col1, #T_8db43_row144_col1, #T_8db43_row145_col1, #T_8db43_row146_col1, #T_8db43_row147_col1, #T_8db43_row148_col1, #T_8db43_row149_col1, #T_8db43_row150_col1, #T_8db43_row151_col1, #T_8db43_row152_col1, #T_8db43_row153_col1, #T_8db43_row154_col1, #T_8db43_row155_col1, #T_8db43_row156_col1, #T_8db43_row157_col1, #T_8db43_row158_col1, #T_8db43_row159_col1, #T_8db43_row160_col1, #T_8db43_row161_col1, #T_8db43_row162_col1, #T_8db43_row163_col1, #T_8db43_row164_col1, #T_8db43_row165_col1, #T_8db43_row166_col1, #T_8db43_row167_col1, #T_8db43_row168_col1, #T_8db43_row169_col1, #T_8db43_row170_col1, #T_8db43_row171_col1, #T_8db43_row172_col1, #T_8db43_row173_col1, #T_8db43_row174_col1, #T_8db43_row175_col1, #T_8db43_row176_col1, #T_8db43_row177_col1, #T_8db43_row178_col1, #T_8db43_row179_col1, #T_8db43_row180_col1, #T_8db43_row181_col1, #T_8db43_row182_col1, #T_8db43_row183_col1, #T_8db43_row184_col1, #T_8db43_row185_col1, #T_8db43_row186_co ...

# %%
styled_median_df.to_excel('../Processed_Data/Output of analysis/median_values_of_exposure_timing.xlsx')

# %%
summary_median_df.to_csv('../Processed_Data/Output of analysis/median_values_of_exposure_timing.csv')
